# %%
import src

# %%
attack = src.read_data('data/attacks.csv')

# %%
attack = src.clean_data(attack)

# %%
hem_attack = src.create_hem_attack(attack)

# %%
year_attack = src.create_year_attack(attack)

# %%
us_attacks = src.create_us_attacks(attack)

# %%
src.export_csv(attack, hem_attack, year_attack, us_attacks)

# %%
attack_year = src.read_attack_year()

# %%
attack_hemisphere = src.read_attack_hemisphere()

# %%
us_attacks = src.read_us_attacks()

# %%
us_attacks
# Out:
#      Case Number            Area Fatal (Y/N) West/East
# 0     2018.06.25      California           N      West
# 1     2017.12.31          Hawaii           N      West
# 2     2016.11.14          Hawaii           N      West
# 3   2015.06.27.b  North Carolina           N      East
# 4   2015.06.14.b  North Carolina           N      East
# 5   2015.06.14.a  North Carolina           N      East
# 6     2015.04.03         Florida           N      East
# 7     2014.09.06         Alabama           N      East
# 8   2014.06.01.c         Florida           N      East
# 9     2013.10.31          Hawaii           N      West
# 10    2013.10.20          Hawaii           N      West
# 11    2013.09.14         Florida           N      East
# 12  2013.04.13.b         Florida           N      East
# 13    2012.10.30      California           N      West
# 14    2012.05.12      California           N      West
# 15    2012.05.06      California           N      West
# ...

# %%
src.prepare_data(attack_year, attack_hemisphere, us_attacks)
# Out:
#       Case Number  year Fatal (Y/N)                         Country
# 103    1977.08.31  1977           N                       AUSTRALIA
# 104    1975.12.06  1975           N                             USA
# 105    1975.08.09  1975           N                             USA
# 106  1975.07.30.a  1975           Y                       AUSTRALIA
# 107    1973.09.09  1973           Y                          MEXICO
# 108    1971.09.07  1971           Y                         CROATIA
# 109    1968.12.25  1968           N                     NEW ZEALAND
# 110    1967.08.19  1967           Y                       AUSTRALIA
# 111    1964.05.08  1964           Y                            FIJI
# 112    1963.12.08  1963           N                       AUSTRALIA
# 113  1963.11.30.a  1963           N                PAPUA NEW GUINEA
# 114    1963.07.28  1963           N  FEDERATED STATES OF MICRONESIA
# 115    1962.09.02  1962           Y                           ITALY
# ...

# %%
src.set_style()

# %%
src.prepare_attack_year(attack_year)
# Out:
#       Case Number  year Fatal (Y/N)                         Country
# 0      2018.06.25  2018           N                             USA
# 1    2018.06.03.a  2018           Y                          BRAZIL
# 2    2018.04.28.b  2018           N                      COSTA RICA
# 3      2018.04.23  2018           N                        MALDIVES
# 4      2018.04.03  2018           N                    SOUTH AFRICA
# 5      2017.12.31  2017           N                             USA
# 6      2017.11.04  2017           Y                            CUBA
# 7      2017.06.02  2017           N                         BAHAMAS
# 8    2017.04.17.a  2017           Y                       AUSTRALIA
# 9      2016.12.01  2016           N                       AUSTRALIA
# 10     2016.11.14  2016           N                             USA
# 11     2016.05.31  2016           Y                       AUSTRALIA
# 12     2015.07.31  2015           N                       AUSTRALIA
# ...

# %%
src.plot_attack_year_violin(attack_year)
# Out:
# <AxesSubplot: title={'center': 'Shark attack fatalities prior to 2000'}, xlabel='Fatal (Y/N)', ylabel='year'>

# %%
src.plot_attack_year_swarm(attack_year)
# Out:
# <AxesSubplot: title={'center': 'Shark attack fatalities by year'}, xlabel='Fatal (Y/N)', ylabel='Year'>

# %%
src.plot_attack_hemisphere_heatmap(attack_hemisphere)
# Out:
# <AxesSubplot: xlabel='Hemisphere', ylabel='Fatal (Y/N)'>

# %%
src.plot_attack_hemisphere_bar(attack_hemisphere)

# %%
src.plot_us_attacktable(us_attacks)
# Out:
# <AxesSubplot: xlabel='West/East', ylabel='Fatal (Y/N)'>

# %%
src.plot_us_attack_bar(us_attacks)
# Out:
# <function src.plot_us_attack_bar(us_attacks)>

# %%
src.dangerous_countries(attack_hemisphere)
