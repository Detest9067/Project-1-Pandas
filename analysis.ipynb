# %%
from IPython.display import display, Image

# %% [markdown]
# ## Hypothesis:Sharks attacks before the year 1980 were always fatal

# %%
links = Image(filename='data/year_plot.png', width = 750, height = 750)
rechts = Image(filename='data/year_swarm.png', width = 750, height = 750)
display(links, rechts)

# %% [markdown]
# ### In the graphic titled "Shark attack fatalities prior to 2000" we can see that there is a clear pattern regarding shark attack fatalities prior to 1920: They're all fatal.
#
# >This is somewhat in line with the original hypothesis of all attacks before 1980 were fatal: The cut off date is many years earlier than expected, likely due to discrepancies with reporting shark attacks.
#
# >Despite this, we can see a clear trend that not only did the number of attacks (recorded attacks) increase greatly after 1920, but the number of fatal attacks remains higher until 1980 (see "Shark attack fatalities by year")

# %% [markdown]
# ## Hypothesis:Shark attacks in the Southern Hemisphere are more likely to be fatal

# %%
izq = Image(filename='data/hemisphere_heatmap.png', width = 750, height = 750)
der = Image(filename='data/hemisphere_bar.png', width = 750, height = 750)
display(izq, der)

# %% [markdown]
# ### If we look at the heatmap, we can see the clear pattern that emerges: The Southern hemisphere has a much higher number of fatal shark attacks than the North.
#
# >The overall number of attacks is also higher in the Southern hemisphere, although interestingly the number of non-fatal attacks is actually higher in the Northern Hemisphere

# %% [markdown]
# ## Hypothesis: West Coast(of the US) Sharks are friendlier than East Coast Sharks

# %%
right = Image(filename='data/us_attack_heatmap.png', width = 750, height = 750)
left = Image(filename='data/us_attack_bar.png', width = 750, height = 750)
display(right, left)

# %% [markdown]
# ### If we look at the heatmap for fatalties by coast, there is some interesting data:
# > both coasts had equal amount of fatal attacks: HOWEVER the West Coast had a larger total number of attacks
# <br><br>
# > the "Fatalities by Coast" graphic gives us a good idea of how many attacks the West Coast had overall when compared to the East Coast

# %% [markdown]
# ## Hypothesis: Swimming in Australia has the highest risk of a fatal shark attack

# %%
Image(filename='data/dangerous_waters.png', width = 750, height = 750)

# %% [markdown]
# ### Lastly, let's look at which country is the most dangerous in terms of Fatal Shark attacks
# <br>
# Looking at the graph, 2 things are clear:
# <br><br>
#
# -The United States has the highest number of non-fatal attacks
# <br><br>
#
# -Australia has less attacks overall, but a much higher number of fatal shark attacks

# %% [markdown]
# ### Conclusions
# 1. Shark attacks before 1980 were mostly fatal, but there is a serious lack of reporting before the 1940's
# 2. Shark attacks are more frequent and deadly in the Southern Hemisphere
# 3. Shark attacks are more frequent on the West Coast of the US, when compared to the East Coast. In both cases, the attack is likely to be non-fatal
# 4. You're more likely to get attacked by a shark in the USA, but a shark attack in Australia is more likely to kill you
